# %%
# ✅ Install dependencies
# !pip install ultralytics roboflow

# ✅ Import libraries
from roboflow import Roboflow
from ultralytics import YOLO

# ✅ Connect to Roboflow
rf = Roboflow(api_key="j1lsR6Qm2ufivlsEEBHa")  # your API key
project = rf.workspace("charls-lab").project("face-recognition-lrmfu")
version = project.version(5)  # or whichever dataset version you want
dataset = version.download("yolov8")

# ✅ Load YOLO model
model = YOLO("yolov8n.pt")  # lightweight model for faster training

# ✅ Train the model (on GPU automatically)
results = model.train(
    data=f"{dataset.location}/data.yaml",
    epochs=50,        # you can adjust epochs
    imgsz=320,        # smaller image size = faster
    batch=8,
    name="face_recognition_run",
    device=0          # force GPU 0
)

print("✅ Training complete! Check the best model at:")
print("runs/detect/face_recognition_run/weights/best.pt")

from google.colab import files
files.download("/content/best.pt")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Ultralytics 8.3.226 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
